# %%
import importlib
import my_tree
importlib.reload(my_tree)
import pandas as pd
from sklearn.model_selection import train_test_split
import time
from sklearn.model_selection import StratifiedKFold


df = pd.read_csv('/Users/dashabalashova/1_1_5_ML_Bioinf/data/spam.csv')
kf = StratifiedKFold(n_splits=5, shuffle=True)

# %%
import sys
import time

N=100

t=time.time()


log_file = open("HW4_5_spam_v3.log","w")
log_file.close()    
t = time.time()    


kf_n = 0
auc_arr = []
df_auc = pd.DataFrame(columns=['kfold', 'depth', 'number of trees', 'ROC AUC', 'arr'])
for train_index, test_index in kf.split(df, df[['label']]):
    train_df = df.iloc[train_index]
    
    validate_df = df.iloc[test_index]
    prediction_array = [[]]*10
    for d in [2, 3, 5, 7, 10]:
        prediction_array[d-1] = validate_df[['label']]
    for i in range(0, N):
        old_stdout = sys.stdout
        log_file = open("HW4_5_spam_v3.log","a+")
        sys.stdout = log_file
        print((time.time()-t)/60)
        t = time.time()
        sys.stdout = old_stdout


        tree = my_tree.make_tree(df = train_df, I_type = 'gini', depth = 10, var_proportion = 0.1)
        
       
        for d in [2, 3, 5, 7, 10]:
            df_prediction = my_tree.tree_impl(df = validate_df, tree = tree, depth = d)
            prediction_array[d-1] = pd.concat([prediction_array[d-1], df_prediction], axis=1)

    for d in [2, 3, 5, 7, 10]:
        df_d = prediction_array[d-1]
        for n in [5, 10, 20, 30, 50, 100]:
            #print('kfold =', kf_n, 'depth =', d, 'number of trees =', n, end=' ')
            auc, R = my_tree.auc(df_d, n)
            auc_arr.append([kf_n, d, n, auc, R])
            
            df_auc = df_auc.append({'kfold':kf_n, 'depth':d, 'number of trees':n, 'ROC AUC':auc, 'arr':R}, ignore_index=True)
               
    kf_n+=1

# %%
import matplotlib.pyplot as plt
from operator import itemgetter

df_auc

dd, nn = df_auc.groupby(['depth','number of trees']).mean().idxmax(axis=0, skipna=True)[0]

#print('depth =', dd, 'number of trees =', nn)

df_auc_3 = df_auc[(df_auc['depth']==dd) & (df_auc['number of trees']==nn)]

max_auc = df_auc_3.loc[df_auc_3['ROC AUC'].idxmax()]
print(df_auc_3.drop(columns='arr'))
plt.figure()
plt.plot(list(zip(*max_auc[4]))[0], list(zip(*max_auc[4]))[1])
plt.show()
# Out:
#     kfold depth number of trees   ROC AUC
# 29      0    10             100  0.972274
# 59      1    10             100  0.971721
# 89      2    10             100  0.974357
# 119     3    10             100  0.976004

# %%
df_auc
# Out:
#     kfold depth number of trees   ROC AUC  \
# 0       0     2               5  0.900064
# 1       0     2              10  0.941502
# 2       0     2              20  0.955464
# 3       0     2              30  0.957522
# 4       0     2              50  0.958475
# 5       0     2             100  0.963684
# 6       0     3               5  0.929614
# 7       0     3              10  0.954708
# 8       0     3              20  0.965454
# 9       0     3              30  0.964822
# 10      0     3              50  0.964911
# 11      0     3             100  0.967335
# 12      0     5               5  0.932480
# 13      0     5              10  0.955674
# 14      0     5              20  0.966031
# 15      0     5              30  0.967461
# 16      0     5              50  0.966683
# 17      0     5             100  0.969815
# 18      0     7               5  0.929303
# 19      0     7              10  0.954227
# 20      0     7              20  0.966187
# 21      0     7              30  0.968115
# 22      0     7              50  0.968038
# 23      0     7             100  0.971055
# 24      0    10               5  0.926118
# 25      0    10              10  0.950174
# 26      0    10              20  0.964834
# 27      0    10              30  0.968083
# 28      0    10              50  0.968843
# 29      0    10             100  0.972274
# ..    ...   ...             ...       ...
# 119     3    10             100  0.976004
# 120     4     2               5  0.893143
# 121     4     2              10  0.895248
# 122     4     2              20  0.938892
# 123     4     2              30  0.945917
# 124     4     2              50  0.949051
# 125     4     2             100  0.954549
# 126     4     3               5  0.913715
# 127     4     3              10  0.925231
# 128     4     3              20  0.953604
# 129     4     3              30  0.957301
# 130     4     3              50  0.957272
# 131     4     3             100  0.963094
# 132     4     5               5  0.929875
# 133     4     5              10  0.945042
# 134     4     5              20  0.962958
# 135     4     5              30  0.963897
# 136     4     5              50  0.964299
# 137     4     5             100  0.968535
# 138     4     7               5  0.931904
# 139     4     7              10  0.947159
# 140     4     7              20  0.965055
# 141     4     7              30  0.966660
# 142     4     7              50  0.967151
# 143     4     7             100  0.971793
# 144     4    10               5  0.929784
# 145     4    10              10  0.944717
# 146     4    10              20  0.966142
# 147     4    10              30  0.967394
# 148     4    10              50  0.967865
#
#                                                    arr
# 0    [[0.0, 0.06887052341597796], [0.00179211469534...
# 1    [[0.0, 0.05234159779614325], [0.0, 0.055096418...
# 2    [[0.0, 0.0027548209366391185], [0.0, 0.0137741...
# 3    [[0.0, 0.0027548209366391185], [0.0, 0.0137741...
# 4    [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 5    [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 6    [[0.0, 0.046831955922865015], [0.0, 0.05234159...
# 7    [[0.0, 0.0027548209366391185], [0.0, 0.0165289...
# 8    [[0.0, 0.0027548209366391185], [0.0, 0.0165289...
# 9    [[0.0, 0.0027548209366391185], [0.0, 0.0082644...
# 10   [[0.0, 0.0027548209366391185], [0.0, 0.0165289...
# 11   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 12   [[0.0, 0.01652892561983471], [0.0, 0.022038567...
# 13   [[0.0, 0.005509641873278237], [0.0, 0.00826446...
# 14   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 15   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 16   [[0.0, 0.0027548209366391185], [0.0, 0.0082644...
# 17   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 18   [[0.0, 0.011019283746556474], [0.0, 0.01377410...
# 19   [[0.0, 0.005509641873278237], [0.0, 0.00826446...
# 20   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 21   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 22   [[0.0, 0.0027548209366391185], [0.0, 0.0137741...
# 23   [[0.0, 0.0027548209366391185], [0.0, 0.0137741...
# 24   [[0.0, 0.005509641873278237], [0.0, 0.01101928...
# 25   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 26   [[0.0, 0.0027548209366391185], [0.0, 0.0055096...
# 27   [[0.0, 0.005509641873278237], [0.0, 0.00826446...
# 28   [[0.0, 0.0027548209366391185], [0.0, 0.0110192...
# 29   [[0.0, 0.0027548209366391185], [0.0, 0.0110192...
# ..                                                 ...
# 119  [[0.0, 0.0027624309392265192], [0.0, 0.0138121...
# 120  [[0.0, 0.052486187845303865], [0.0, 0.06077348...
# 121  [[0.0, 0.027624309392265192], [0.0, 0.03038674...
# 122  [[0.0, 0.016574585635359115], [0.0, 0.02486187...
# 123  [[0.0, 0.013812154696132596], [0.0, 0.01657458...
# 124  [[0.0, 0.0055248618784530384], [0.0, 0.0082872...
# 125  [[0.0, 0.0055248618784530384], [0.0, 0.0082872...
# 126  [[0.0, 0.0055248618784530384], [0.0, 0.0359116...
# 127  [[0.0, 0.019337016574585635], [0.0, 0.02209944...
# 128  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 129  [[0.0, 0.0027624309392265192], [0.0, 0.0082872...
# 130  [[0.0, 0.0027624309392265192], [0.0, 0.0082872...
# 131  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 132  [[0.0, 0.016574585635359115], [0.0, 0.02762430...
# 133  [[0.0, 0.008287292817679558], [0.0, 0.01104972...
# 134  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 135  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 136  [[0.0, 0.0027624309392265192], [0.0, 0.0082872...
# 137  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 138  [[0.0, 0.024861878453038673], [0.0, 0.03314917...
# 139  [[0.0, 0.008287292817679558], [0.0, 0.01657458...
# 140  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 141  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 142  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 143  [[0.0, 0.0027624309392265192], [0.0, 0.0055248...
# 144  [[0.0, 0.0055248618784530384], [0.0, 0.0635359...
# 145  [[0.0, 0.0055248618784530384], [0.0, 0.0165745...
# 146  [[0.0, 0.0027624309392265192], [0.0, 0.0082872...
# 147  [[0.0, 0.0027624309392265192], [0.0, 0.0082872...
# 148  [[0.0, 0.0027624309392265192], [0.0, 0.0082872...
#
# [149 rows x 5 columns]
